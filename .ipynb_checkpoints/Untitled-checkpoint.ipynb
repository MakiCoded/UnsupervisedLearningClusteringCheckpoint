# %%
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import linkage, dendrogram

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.decomposition import PCA

# %%
data= pd.read_csv("Credit_card_dataset.csv")

# %% [markdown]
# # Basic data exploration())

# %%
print(data.head())
print(data.info())
print(data.describe())
# Out:
#   CUST_ID  BALANCE_FREQUENCY  PURCHASES     PAYMENTS  CREDIT_LIMIT  \
# 0  C10001           0.818182      95.40   201.802084        1000.0
# 1  C10002           0.909091       0.00  4103.032597        7000.0
# 2  C10003           1.000000     773.17   622.066742        7500.0
# 3  C10004           0.636364    1499.00     0.000000        7500.0
# 4  C10005           1.000000      16.00   678.334763        1200.0
#
#    CASH_ADVANCE
# 0      0.000000
# 1   6442.945483
# 2      0.000000
# 3    205.788017
# 4      0.000000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CUST_ID            8950 non-null   object
#  1   BALANCE_FREQUENCY  8950 non-null   float64
#  2   PURCHASES          8950 non-null   float64
#  3   PAYMENTS           8950 non-null   float64
#  4   CREDIT_LIMIT       8949 non-null   float64
# ...

# %% [markdown]
# # Data preparation

# %%
# Handling missing values

# %%
data = data.dropna()

# %% [markdown]
# # Handling outliers

# %%
for column in ['PURCHASES', 'CREDIT_LIMIT']:
    q1 = data[column].quantile(0.25)
    q3 = data[column].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    data = data[(data[column] >= lower_bound) & (data[column] <= upper_bound)]

# %% [markdown]
# # Feature scaling

# %%
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data[['PURCHASES', 'CREDIT_LIMIT']])

# %% [markdown]
# # Hierarchical clustering

# %%
linked = linkage(data_scaled, method='ward')
plt.figure(figsize=(10, 7))
dendrogram(linked)
plt.title('Hierarchical Clustering Dendrogram')
plt.show()

# %% [markdown]
# # K-means clustering

# %%
kmeans = KMeans(n_clusters=3, random_state=10)
kmeans.fit(data_scaled)
data['Cluster'] = kmeans.labels_

# %% [markdown]
# # Plotting K-means clusters

# %%
plt.figure(figsize=(10, 7))
sns.scatterplot(x=data['PURCHASES'], y=data['CREDIT_LIMIT'], hue=data['Cluster'], palette='viridis')
plt.title('K-means Clustering')
plt.show()

# %% [markdown]
# # Finding the best k value using the elbow method

# %%
inertia = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(data_scaled)
    inertia.append(kmeans.inertia_)

# %%
plt.figure(figsize=(10, 7))
plt.plot(range(1, 11), inertia, marker='o')
plt.title('Elbow Method for Optimal k')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()

# %% [markdown]
# # Re-plotting with the best k value

# %%
best_k = 3  # Assuming 3 is the best k value from the elbow plot
kmeans = KMeans(n_clusters=best_k)
kmeans.fit(data_scaled)
data['Cluster'] = kmeans.labels_

# %%
plt.figure(figsize=(10, 7))
sns.scatterplot(x=data['PURCHASES'], y=data['CREDIT_LIMIT'], hue=data['Cluster'], palette='viridis')
plt.title('K-means Clustering with Optimal k')
plt.show()

# %% [markdown]
# # Interpretation of results

# %%
print(data.groupby('Cluster').mean())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\.conda\envs\notebook-7.0.6_9\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File ~\.conda\envs\notebook-7.0.6_9\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~\.conda\envs\notebook-7.0.6_9\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
# ...
